# %%
import pandas as pd

# %%
df = pd.read_csv('/dk/baa/dat/ali.csv', header=0)

# %%
dir(df)
# Out:
# ['Close',
#  'Date',
#  'High',
#  'Low',
#  'Open',
#  'T',
#  'Volume',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
# ...

# %%
df.tail(10)
# Out:
#            Date       Open       High        Low      Close     Volume  \
# 367  2014-10-02  86.269997  88.199997  85.611000  87.059998   21469700
# 368  2014-10-01  88.699997  88.940002  86.040001  86.099998   24029600
# 369  2014-09-30  89.000000  90.879997  88.459999  88.849998   24419400
# 370  2014-09-29  89.620003  89.699997  88.019997  88.750000   25302000
# 371  2014-09-26  89.730003  90.459999  88.660004  90.459999   18340000
# 372  2014-09-25  91.089996  91.500000  88.500000  88.919998   28598000
# 373  2014-09-24  88.470001  90.570000  87.220001  90.570000   32088000
# 374  2014-09-23  88.940002  90.480003  86.620003  87.169998   39009800
# 375  2014-09-22  92.699997  92.949997  89.500000  89.889999   66657800
# 376  2014-09-19  92.699997  99.699997  89.949997  93.889999  271879400
#
#      Adj Close
# 367  87.059998
# 368  86.099998
# 369  88.849998
# 370  88.750000
# 371  90.459999
# 372  88.919998
# 373  90.570000
# 374  87.169998
# 375  89.889999
# 376  93.889999

# %%
df.head(10)
# Out:
#          Date       Open       High        Low      Close    Volume  Adj Close
# 0  2016-03-18  74.970001  76.300003  74.709999  76.250000  13325700  76.250000
# 1  2016-03-17  73.760002  74.370003  73.510002  74.250000   9420000  74.250000
# 2  2016-03-16  72.010002  73.660004  71.860001  73.500000   7670200  73.500000
# 3  2016-03-15  72.620003  72.839996  71.750000  72.230003   8355000  72.230003
# 4  2016-03-14  74.010002  74.419998  72.889999  73.349998  11056400  73.349998
# 5  2016-03-11  72.580002  74.010002  72.220001  74.010002  11167100  74.010002
# 6  2016-03-10  72.500000  73.050003  70.605003  71.970001  11245700  71.970001
# 7  2016-03-09  71.589996  72.610001  70.680000  72.430000   7271800  72.430000
# 8  2016-03-08  72.400002  72.650002  70.959999  71.070000   8657900  71.070000
# 9  2016-03-07  72.199997  73.980003  72.000000  72.889999  11030000  72.889999

# %%
type(df['Open'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e5e5305ee160> in <module>()
# ----> 1 type(df['Open'])
#
# NameError: name 'df' is not defined

# %%
# %pylab inline
import pandas as pd
df = pd.read_csv('/dk/baa/dat/ali.csv', header=0)
df.plot(x='Date', y=['Open', 'High'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df['Date'][::-1]
# Out:
# 376    2014-09-19
# 375    2014-09-22
# 374    2014-09-23
# 373    2014-09-24
# 372    2014-09-25
# 371    2014-09-26
# 370    2014-09-29
# 369    2014-09-30
# 368    2014-10-01
# 367    2014-10-02
# 366    2014-10-03
# 365    2014-10-06
# 364    2014-10-07
# 363    2014-10-08
# 362    2014-10-09
# 361    2014-10-10
# 360    2014-10-13
# 359    2014-10-14
# 358    2014-10-15
# 357    2014-10-16
# 356    2014-10-17
# 355    2014-10-20
# 354    2014-10-21
# 353    2014-10-22
# 352    2014-10-23
# 351    2014-10-24
# 350    2014-10-27
# 349    2014-10-28
# 348    2014-10-29
# 347    2014-10-30
#           ...
# 29     2016-02-05
# 28     2016-02-08
# 27     2016-02-09
# 26     2016-02-10
# 25     2016-02-11
# 24     2016-02-12
# 23     2016-02-16
# 22     2016-02-17
# 21     2016-02-18
# 20     2016-02-19
# 19     2016-02-22
# 18     2016-02-23
# 17     2016-02-24
# 16     2016-02-25
# 15     2016-02-26
# 14     2016-02-29
# 13     2016-03-01
# 12     2016-03-02
# 11     2016-03-03
# ...

# %%
df = pd.read_csv('/dk/baa/dat/ali_r.csv', header=0)
df.plot(x='Date', y=['Open', 'High'])
